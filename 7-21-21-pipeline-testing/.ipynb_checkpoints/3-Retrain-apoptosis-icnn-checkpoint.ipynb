# %%
import sys
# insert at 1, 0 is the script path (or '' in REPL)
# These top lines are critical for import from another folder
sys.path.insert(1, '/net/capricorn/home/xing/huijing/Segmentation/scripts/Image_analysis_pipeline_vim_dic/')

import numpy as np
import os
import shutil

from cnn_prep_data import prep_icnn_am_train_data
import train_icnn_am
import sbatch_jobs
import pipe_util2

# %% [markdown]
# # Training apoptosis icnn
#
# The single cell picking iis in the 2-Prepare-single-cell-imgs-for-am-training.ipynb
#
# #### Note:
#
# This step require training data.
#
# You can create a ./testing folder using 2-Prepare-single-cell-imgs-for-am-training scripts.

# %% [markdown]
# ### Training in python

# %%
train_folder = "./icnn_am_testing/"
weight = "./sample_data/models/am_icnn_weights/062121_dld1B102_am.hdf5"

# %%
# Try training function in notebook. 
train_icnn_am.icnn_am_train(train_folder, weight)
# Out:
# WARNING:tensorflow:From /net/capricorn/home/xing/huijing/.conda/envs/tf1/lib/python3.7/site-packages/tensorflow_core/python/ops/resource_variable_ops.py:1630: calling BaseResourceVariable.__init__ (from tensorflow.python.ops.resource_variable_ops) with constraint is deprecated and will be removed in a future version.
# Instructions for updating:
# If using Keras pass *_constraint arguments to layers.
# WARNING:tensorflow:From /net/capricorn/home/xing/huijing/.conda/envs/tf1/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4070: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# WARNING:tensorflow:From /net/capricorn/home/xing/huijing/.conda/envs/tf1/lib/python3.7/site-packages/keras/backend/tensorflow_backend.py:4074: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# Model: "resnet50"
# __________________________________________________________________________________________________
# ...

# %% [markdown]
# ### Training in sbatch

# %%
# submit job to cluster.
scr_folder = "./scripts/"
weight = "/net/capricorn/home/xing/huijing/Segmentation/scripts/Image_analysis_pipeline_vim_dic/7-21-21-pipeline-testing/sample_data/models/am_icnn_weights/062121_dld1B102_am.hdf5"
name = "062121_dld1B202"
sbatch_jobs.sbatch_job_icnn_am(scr_folder, train_folder, weight, name = None)
